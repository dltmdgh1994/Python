# %%
import pandas as pd
import sqlalchemy
import pymysql
pymysql.install_as_MySQLdb()

conn = sqlalchemy.create_engine('mysql://DA_SeoulBike:engineering403@leejs-dbins.cuqks267yd6q.ap-northeast-2.rds.amazonaws.com:3306/teamdata', encoding='utf-8')

query1 = ("SELECT 대여소,월,화,수,목,금,토,일,sum(대여횟수) FROM teamdata.RentRecord_by_day rd inner join Day_Info di on rd.대여일 = di.날짜 where 대여소 = 207 or 대여소 = 502 or 대여소 = 113 or 대여소 = 1210 or 대여소 = 2102 or 대여소 = 2219 or 대여소 = 152 or 대여소 = 1308 or 대여소 = 1906 or 대여소 = 210 or 대여소 = 106 or 대여소 = 501 or 대여소 = 590 or 대여소 = 907 or 대여소 = 358 or 대여소 =1222 or 대여소 = 247 or 대여소 = 703 or 대여소 = 816 or 대여소 = 183 or 대여소 = 102 or 대여소 = 259 or 대여소 = 421 or 대여소 = 565 or 대여소 = 2002 or 대여소 = 1211 or 대여소 = 114 or 대여소 = 500 or 대여소 = 540 or 대여소 = 144 or 대여소 = 419 or 대여소 = 525 group by 대여소,월,화,수,목,금,토,일;")
data1 = pd.read_sql(sql=query1, con=conn)
data1.columns = ['Station','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','Num']

# %%
data1
# Out:
#      Station  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday  \
# 0        102       0        0          0         0       1         0       0
# 1        102       0        0          0         0       0         1       0
# 2        102       0        0          0         0       0         0       1
# 3        102       1        0          0         0       0         0       0
# 4        102       0        1          0         0       0         0       0
# 5        102       0        0          1         0       0         0       0
# 6        102       0        0          0         1       0         0       0
# 7        106       0        0          0         0       1         0       0
# 8        106       0        0          0         0       0         1       0
# 9        106       0        0          0         0       0         0       1
# 10       106       1        0          0         0       0         0       0
# ...

# %%
col = []
for i in range(0,224):
    if(data1['Monday'][i] == 1):
        col.append("Monday")
    elif(data1['Tuesday'][i] == 1):
        col.append("Tuesday")
    elif(data1['Wednesday'][i] == 1):
        col.append("Wednesday")
    elif(data1['Thursday'][i] == 1):
        col.append("Thursday")
    elif(data1['Friday'][i] == 1):
        col.append("Friday")
    elif(data1['Saturday'][i] == 1):
        col.append("Saturday")
    elif(data1['Sunday'][i] == 1):
        col.append("Sunday")
    else:
        col.append("A")
    
col
# Out:
# ['Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
# ...

# %%
data1["day"] = col

# %%
del data1['Monday']
del data1['Tuesday']
del data1['Wednesday']
del data1['Thursday']
del data1['Friday']
del data1['Saturday']
del data1['Sunday']

data1
# Out:
#      Station     Num        day
# 0        102  3930.0     Friday
# 1        102  4093.0   Saturday
# 2        102  3468.0     Sunday
# 3        102  3351.0     Monday
# 4        102  3533.0    Tuesday
# 5        102  3402.0  Wednesday
# 6        102  3393.0   Thursday
# 7        106  4088.0     Friday
# 8        106  5421.0   Saturday
# 9        106  4857.0     Sunday
# 10       106  3684.0     Monday
# 11       106  3601.0    Tuesday
# 12       106  3553.0  Wednesday
# 13       106  3535.0   Thursday
# 14       113  8933.0     Friday
# 15       113  9184.0   Saturday
# 16       113  7289.0     Sunday
# 17       113  7367.0     Monday
# 18       113  7840.0    Tuesday
# 19       113  7533.0  Wednesday
# 20       113  7956.0   Thursday
# 21       114  3767.0     Friday
# 22       114  3708.0   Saturday
# 23       114  3259.0     Sunday
# 24       114  3140.0     Monday
# 25       114  3266.0    Tuesday
# 26       114  3248.0  Wednesday
# 27       114  3326.0   Thursday
# ...

# %%
import seaborn as sns

data1 = data1.pivot("day","Station","Num")
data1
# Out:
# Station      102     106     113     114     144     152     183      207   \
# day
# Friday     3930.0  4088.0  8933.0  3767.0  3722.0  5030.0  4112.0  11074.0
# Monday     3351.0  3684.0  7367.0  3140.0  3280.0  4639.0  3471.0  10297.0
# Saturday   4093.0  5421.0  9184.0  3708.0  3836.0  7792.0  3855.0  14924.0
# Sunday     3468.0  4857.0  7289.0  3259.0  2949.0  6878.0  3184.0  12992.0
# Thursday   3393.0  3535.0  7956.0  3326.0  3220.0  4155.0  3625.0   8876.0
# Tuesday    3533.0  3601.0  7840.0  3266.0  3373.0  4540.0  3835.0   9699.0
# Wednesday  3402.0  3553.0  7533.0  3248.0  3137.0  4329.0  3630.0   9539.0
#
# Station      210     247   ...    816     907     1210    1211    1222  \
# day                        ...
# Friday     4357.0  4214.0  ...  3894.0  4067.0  6658.0  3501.0  3971.0
# Monday     3988.0  3991.0  ...  3417.0  3940.0  5854.0  2954.0  3533.0
# Saturday   4624.0  4329.0  ...  4611.0  4723.0  8344.0  3981.0  5429.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize =(25,25))
sns.heatmap(data1, annot = True, fmt ="f")
plt.show()
